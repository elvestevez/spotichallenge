# %% [markdown]
# ![spotify_logo](../img/spotify_logo.png)
#
# # Spotify REST API Challenge
#
# __What to listen?__
#
# Create your own playlist based on the related artists and their most popular tracks using the [Spotify REST API](https://developer.spotify.com/)

# %%
# imports

import pandas as pd
import requests

# %% [markdown]
# ### Get access!!!
#
# Get your `client_id` and `client_secret` to generate your __token__ access

# %%
# generate token with a POST request

client_id = '' # CLIENT ID
client_secret = '' # CLIENT SECRET
auth_url = 'https://accounts.spotify.com/api/token'

# %%
auth_response = requests.post(auth_url, {'grant_type': 'client_credentials',
                                         'client_id': client_id,
                                         'client_secret': client_secret}).json()

# %%
access_token = auth_response['access_token']
auth_response
# Out:
# {'access_token': 'BQCsRlzAJ1nKY73yuu1Zg0PxgrPYa1V4lb7yPJ45T24C5YXDMbJOYfFH_WbUaQNzLPTrGposj7Z14KjJnyWIijn8s5VRDP8hv-CrkCB4kh3L2uEUwVI',
#  'token_type': 'Bearer',
#  'expires_in': 3600}

# %% [markdown]
# ### Set your main variables!!!
#
# Set the `base_url` (i.e.: End-point), parameters and `headers` for your __GET__ operations

# %%
# setting the main variables

base_url = 'https://api.spotify.com/v1'
header = {'Authorization': 'Bearer {token}'.format(token=access_token)}
header
# Out:
# {'Authorization': 'Bearer BQCsRlzAJ1nKY73yuu1Zg0PxgrPYa1V4lb7yPJ45T24C5YXDMbJOYfFH_WbUaQNzLPTrGposj7Z14KjJnyWIijn8s5VRDP8hv-CrkCB4kh3L2uEUwVI'}

# %% [markdown]
# ### Create your new playlist!!!
#
# Use [`/related-artists`](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-an-artists-related-artists) and [`/top-tracks`](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-an-artists-top-tracks) in order to get the data that you need
#
# __Here you have the different artists to start with:__
#
# _Option 1:_ 711MCceyCBcFnzjGY4Q7Un
#
# _Option 2:_ 5gs3QMiBgkUgNofeA16Awv
#
# _Option 3:_ 1ZcvF2meiXi5UPDJWxrKR5
#
# _Option 4:_ 0HSGpDMeXaEmH5aUIHjnBF
#
# _Option 5:_ 5TYxZTjIPqKM8K8NuP9woO
#
# _Option 6:_ 36QJpDe2go2KgaRleHCDTp
#
# _Option 7:_ 3qm84nBOXUEQ2vnTfUTTFC
#
# _Option 8:_ 4NJhFmfw43RLBLjQvxDuRS
#
# _Option 9:_ 0L8ExT028jH3ddEcZwqJJ5
#
# _Option 10:_ 1vCWHaC5f2uS3yhpwWbIA6
#
# _Option 11:_ 1dfeR4HaWDbWqFHLkxsg1d
#
# _Option 12:_ 6ogn9necmbUdCppmNnGOdi

# %% [markdown]
# ---

# %%
# function: get tracks for an id artist
def get_tracks(id_artist):
    resource = '/artists'
    parameters = f'/{id_artist}/top-tracks?market=ES'

    url = base_url + resource + parameters
    
    response = requests.get(url, headers=header).json()
    df_tracks = pd.DataFrame(response['tracks'])[['id','href','name','uri']]
    # include in dataframe selected id artist 
    df_tracks['related_id'] = id_artist
    
    return df_tracks

# %%
# identify an id artist to start process
id_selected = '1dfeR4HaWDbWqFHLkxsg1d'

# %%
# get info artist for a selected id artist
resource = '/artists'
parameters = f'/{id_selected}'

url = base_url + resource + parameters
print(url)

response = requests.get(url, headers=header).json()
dict_artist = dict((k, [response[k]]) for k in ['id', 'name'] if k in response)
df_artist = pd.DataFrame(dict_artist)
# rename columns
df_artist = df_artist.rename(columns={'id': 'artist_id', 'name': 'artist_name'})
df_artist
# Out:
# https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d
#                 artist_id artist_name
# 0  1dfeR4HaWDbWqFHLkxsg1d       Queen

# %%
# get related artist for a selected id artist
resource = '/artists'
parameters = f'/{id_selected}/related-artists'

url = base_url + resource + parameters
print(url)

response = requests.get(url, headers=header).json()
df_related_artists = pd.DataFrame(response['artists'])[['id','name']]
# rename columns
df_related_artists = df_related_artists.rename(columns={'id': 'related_id', 'name': 'related_name'})
# include in dataframe selected id artist 
df_related_artists['artist_id'] = id_selected
# join artist and related artist to merge info
df_related_artists = pd.merge(df_related_artists, df_artist, on='artist_id')
df_related_artists
# Out:
# https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d/related-artists
#                 related_id              related_name               artist_id  \
# 0   4M1FpEWs2PeYfJe7xxJfhH           Freddie Mercury  1dfeR4HaWDbWqFHLkxsg1d
# 1   7jefIIksOi1EazgRTfW2Pk  Electric Light Orchestra  1dfeR4HaWDbWqFHLkxsg1d
# 2   7Ey4PD4MYsKc5I2dolUwbH                 Aerosmith  1dfeR4HaWDbWqFHLkxsg1d
# 3   0oSGxfWSnnOXhD2fKuz2Gy               David Bowie  1dfeR4HaWDbWqFHLkxsg1d
# 4   3PhoLpVuITZKcymswpck5b                Elton John  1dfeR4HaWDbWqFHLkxsg1d
# 5   67ea9eGLXYMsO2eYQRui3w                   The Who  1dfeR4HaWDbWqFHLkxsg1d
# 6   07XSN3sPlIlB2L2XNcTwJw                      KISS  1dfeR4HaWDbWqFHLkxsg1d
# 7   2cnMpRsOVqtPMfq7YiFE6K                 Van Halen  1dfeR4HaWDbWqFHLkxsg1d
# 8   0rvjqX7ttXeg3mTy8Xscbt                   Journey  1dfeR4HaWDbWqFHLkxsg1d
# 9   36QJpDe2go2KgaRleHCDTp              Led Zeppelin  1dfeR4HaWDbWqFHLkxsg1d
# 10  3JsMj0DEzyWc0VDlHuy9Bx                Supertramp  1dfeR4HaWDbWqFHLkxsg1d
# 11  0PFtn5NtBbbUNbU9EAmIWF                      TOTO  1dfeR4HaWDbWqFHLkxsg1d
# 12  568ZhdwyaiCyOGJRtNYhWf               Deep Purple  1dfeR4HaWDbWqFHLkxsg1d
# 13  29kkCKKGXheHuoO829FxWK                    Boston  1dfeR4HaWDbWqFHLkxsg1d
# 14  6zFYqv1mOsgBRQbae3JJ9e                Billy Joel  1dfeR4HaWDbWqFHLkxsg1d
# 15  4salDzkGmfycRqNUbyBphh                      Styx  1dfeR4HaWDbWqFHLkxsg1d
# 16  4x1nvY2FN8jxqAFA0DA02H               John Lennon  1dfeR4HaWDbWqFHLkxsg1d
# 17  3sFhA6G1N0gG1pszb6kk1m                     Wings  1dfeR4HaWDbWqFHLkxsg1d
# 18  7FIoB5PHdrMZVC3q2HE5MS           George Harrison  1dfeR4HaWDbWqFHLkxsg1d
# 19  3dBVyJ7JuOMt4GE9607Qin                    T. Rex  1dfeR4HaWDbWqFHLkxsg1d
#
#    artist_name
# 0        Queen
# 1        Queen
# 2        Queen
# 3        Queen
# 4        Queen
# 5        Queen
# 6        Queen
# 7        Queen
# 8        Queen
# 9        Queen
# 10       Queen
# 11       Queen
# 12       Queen
# 13       Queen
# 14       Queen
# 15       Queen
# 16       Queen
# 17       Queen
# 18       Queen
# 19       Queen

# %%
# get tracks for id related artist from a selected id artist
df_related_tracks = pd.DataFrame()
for i in df_related_artists['related_id']:
    df_tracks = get_tracks(i)
    df_related_tracks = pd.concat([df_related_tracks, df_tracks])

# rename columns
df_related_tracks = df_related_tracks.rename(columns={'id': 'track_id', 'href': 'track_href', 'name': 'track_name', 'uri': 'track_uri'})
# join related artist and track related artist to merge info
df_related_tracks = pd.merge(df_related_tracks, df_related_artists, on='related_id')
df_related_tracks
# Out:
#                    track_id  \
# 0    361VJCtpxxjA32lh4P0jZU
# 1    4xm2RpQtpFVlPlO1v4BrBr
# 2    14FAtIQZsRYeu8zVI33l7f
# 3    6cNTGVmP2CzJpLQ01QIaD0
# 4    3BdId1EhcMX7yAzwzQJLAD
# ..                      ...
# 195  7as3y0Z9c0LH4sZDhFw9uU
# 196  0tK1Ya57nOsgD0nGndjpdI
# 197  5BUVbe6Zt1jVgKFKMdp0p0
# 198  4FHGKscCEnhBSyszmL32L0
# 199  5KGZcnxuhwvfHyd6pcY2wd
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/361VJCtpxxjA...
# 1    https://api.spotify.com/v1/tracks/4xm2RpQtpFVl...
# 2    https://api.spotify.com/v1/tracks/14FAtIQZsRYe...
# 3    https://api.spotify.com/v1/tracks/6cNTGVmP2CzJ...
# 4    https://api.spotify.com/v1/tracks/3BdId1EhcMX7...
# ..                                                 ...
# 195  https://api.spotify.com/v1/tracks/7as3y0Z9c0LH...
# 196  https://api.spotify.com/v1/tracks/0tK1Ya57nOsg...
# 197  https://api.spotify.com/v1/tracks/5BUVbe6Zt1jV...
# 198  https://api.spotify.com/v1/tracks/4FHGKscCEnhB...
# 199  https://api.spotify.com/v1/tracks/5KGZcnxuhwvf...
#
#                                         track_name  \
# 0    Living On My Own - No More Brothers Radio Mix
# 1                              The Great Pretender
# 2                           I Was Born to Love You
# 3                   Living on My Own - Single Edit
# 4                                        Barcelona
# ..                                             ...
# 195          Children of the Revolution - Remaster
# 196     Bang A Gong (Get It On) (Electric Version)
# 197                                       Jeepster
# 198                                      Mambo Sun
# 199                              Ride A White Swan
#
#                                 track_uri              related_id  \
# 0    spotify:track:361VJCtpxxjA32lh4P0jZU  4M1FpEWs2PeYfJe7xxJfhH
# 1    spotify:track:4xm2RpQtpFVlPlO1v4BrBr  4M1FpEWs2PeYfJe7xxJfhH
# 2    spotify:track:14FAtIQZsRYeu8zVI33l7f  4M1FpEWs2PeYfJe7xxJfhH
# 3    spotify:track:6cNTGVmP2CzJpLQ01QIaD0  4M1FpEWs2PeYfJe7xxJfhH
# 4    spotify:track:3BdId1EhcMX7yAzwzQJLAD  4M1FpEWs2PeYfJe7xxJfhH
# ..                                    ...                     ...
# 195  spotify:track:7as3y0Z9c0LH4sZDhFw9uU  3dBVyJ7JuOMt4GE9607Qin
# 196  spotify:track:0tK1Ya57nOsgD0nGndjpdI  3dBVyJ7JuOMt4GE9607Qin
# 197  spotify:track:5BUVbe6Zt1jVgKFKMdp0p0  3dBVyJ7JuOMt4GE9607Qin
# 198  spotify:track:4FHGKscCEnhBSyszmL32L0  3dBVyJ7JuOMt4GE9607Qin
# 199  spotify:track:5KGZcnxuhwvfHyd6pcY2wd  3dBVyJ7JuOMt4GE9607Qin
#
#         related_name               artist_id artist_name
# 0    Freddie Mercury  1dfeR4HaWDbWqFHLkxsg1d       Queen
# 1    Freddie Mercury  1dfeR4HaWDbWqFHLkxsg1d       Queen
# 2    Freddie Mercury  1dfeR4HaWDbWqFHLkxsg1d       Queen
# 3    Freddie Mercury  1dfeR4HaWDbWqFHLkxsg1d       Queen
# 4    Freddie Mercury  1dfeR4HaWDbWqFHLkxsg1d       Queen
# ..               ...                     ...         ...
# 195           T. Rex  1dfeR4HaWDbWqFHLkxsg1d       Queen
# 196           T. Rex  1dfeR4HaWDbWqFHLkxsg1d       Queen
# 197           T. Rex  1dfeR4HaWDbWqFHLkxsg1d       Queen
# 198           T. Rex  1dfeR4HaWDbWqFHLkxsg1d       Queen
# 199           T. Rex  1dfeR4HaWDbWqFHLkxsg1d       Queen
#
# [200 rows x 8 columns]

# %% [markdown]
# ###  Create playlist

# %%
# get playlists
resource = '/users'
parameters = '/elv.estevez/playlists'

url = base_url + resource + parameters
print(url)

response = requests.get(url, headers=header).json()
df_playlists = pd.DataFrame(response['items'])[['id','name','href','tracks','public']]
df_playlists
# Out:
# https://api.spotify.com/v1/users/elv.estevez/playlists
#                        id                                               name  \
# 0  3UrzAcsfRRKspBViXRDNSm                                            testing
# 1  5WGosCb6pZjR1YccTORk8m  Various Artists — Música Infantil y Bandas Son...
# 2  3vfCeU4brnIP2m2eYU3Hjx  Musica Infantil Piano — Las mejores canciones ...
# 3  3Dy42r52mEFBVHaaTFMZyv                              ROSALÍA — Los Ángeles
# 4  2cYBgjTtWo9a40xZGgAb0q                            ROSALÍA — El Mal Querer
# 5  6tcGPrI5Pp9JvRkEyWxRvD                                         Indie Folk
# 6  4rbJprcXzzeVUZ3GPuQY1l                              Mad Cool 2017 Selecto
#
#                                                 href  \
# 0  https://api.spotify.com/v1/playlists/3UrzAcsfR...
# 1  https://api.spotify.com/v1/playlists/5WGosCb6p...
# 2  https://api.spotify.com/v1/playlists/3vfCeU4br...
# 3  https://api.spotify.com/v1/playlists/3Dy42r52m...
# 4  https://api.spotify.com/v1/playlists/2cYBgjTtW...
# 5  https://api.spotify.com/v1/playlists/6tcGPrI5P...
# 6  https://api.spotify.com/v1/playlists/4rbJprcXz...
#
#                                               tracks  public
# 0  {'href': 'https://api.spotify.com/v1/playlists...    True
# 1  {'href': 'https://api.spotify.com/v1/playlists...    True
# 2  {'href': 'https://api.spotify.com/v1/playlists...    True
# 3  {'href': 'https://api.spotify.com/v1/playlists...    True
# 4  {'href': 'https://api.spotify.com/v1/playlists...    True
# 5  {'href': 'https://api.spotify.com/v1/playlists...    True
# 6  {'href': 'https://api.spotify.com/v1/playlists...    True

# %%
# get tracks playlist
resource = '/users'
parameters = '/elv.estevez/playlists/3UrzAcsfRRKspBViXRDNSm/tracks'

url = base_url + resource + parameters
print(url)

response = requests.get(url, headers=header).json()
df_playlist_tracks = pd.DataFrame(response['items'])[['track']]
df_playlist_tracks = pd.json_normalize(df_playlist_tracks['track'])[['id', 'name', 'href','uri']]
df_playlist_tracks
# Out:
# https://api.spotify.com/v1/users/elv.estevez/playlists/3UrzAcsfRRKspBViXRDNSm/tracks
#                        id                         name  \
# 0  3z8h0TU7ReDPLIbEnYhWZb            Bohemian Rhapsody
# 1  7iN1s7xHE4ifF5povM6A48  Let It Be - Remastered 2009
#
#                                                 href  \
# 0  https://api.spotify.com/v1/tracks/3z8h0TU7ReDP...
# 1  https://api.spotify.com/v1/tracks/7iN1s7xHE4if...
#
#                                     uri
# 0  spotify:track:3z8h0TU7ReDPLIbEnYhWZb
# 1  spotify:track:7iN1s7xHE4ifF5povM6A48

# %%
# add tracks playlist
resource = '/users'
uri = '?uris=spotify:track:361VJCtpxxjA32lh4P0jZU'
parameters = f'/elv.estevez/playlists/3UrzAcsfRRKspBViXRDNSm/tracks{uri}'

url = base_url + resource + parameters
print(url)

response = requests.post(url, headers=header).json()
response
# Out:
# https://api.spotify.com/v1/users/elv.estevez/playlists/3UrzAcsfRRKspBViXRDNSm/tracks?uris=spotify:track:361VJCtpxxjA32lh4P0jZU
# {'error': {'status': 403,
#   'message': 'This request requires user authentication.'}}

# %%
# create empty playlist
resource = '/users'
playlist = '?name=myPlaylist&description=myPlaylistDescription&public=false'
parameters = f'/elv.estevez/playlists{playlist}'

url = base_url + resource + parameters
print(url)

response = requests.post(url, headers=header).json()
response
# Out:
# https://api.spotify.com/v1/users/elv.estevez/playlists?name=myPlaylist&description=myPlaylistDescription&public=false
# {'error': {'status': 403,
#   'message': 'This request requires user authentication.'}}

# %% [markdown]
# You can always try with the [wrapper](https://github.com/plamere/spotipy)!!!
#
# ![I quit](https://media.giphy.com/media/3oFzlXPvXYZ4q8VQOs/giphy.gif)
